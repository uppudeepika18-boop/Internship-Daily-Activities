# %% [markdown]
# # underfitting data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
df=pd.read_csv(r"D:\overfitting_dataset.csv")
df
# Out:
#     Study_Hours  Marks
# 0             1      5
# 1             2      1
# 2             3      8
# 3             4      2
# 4             5      9
# 5             6      3
# 6             7     10
# 7             8      4
# 8             9     11
# 9            10      5
# 10            1      6
# 11            2      2
# 12            3      9
# 13            4      3
# 14            5     10
# 15            6      4
# 16            7     11
# 17            8      5
# 18            9     12
# 19           10      6

# %%
X = df[["Study_Hours"]]
Y = df["Marks"]
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.4)
X_train
# Out:
#     Study_Hours
# 17            8
# 3             4
# 10            1
# 14            5
# 19           10
# 5             6
# 1             2
# 9            10
# 11            2
# 0             1
# 15            6
# 12            3

# %%
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_train_pred = model.predict(X_train)
Y_test_pred = model.predict(X_test)

# %%
Y_train_pred
# Out:
# array([5.2074928 , 4.73487032, 4.38040346, 4.85302594, 5.44380403,
#        4.97118156, 4.49855908, 5.44380403, 4.49855908, 4.38040346,
#        4.97118156, 4.6167147 ])

# %%
Y_test_pred
# Out:
# array([5.08933718, 4.6167147 , 4.85302594, 4.73487032, 5.32564841,
#        5.32564841, 5.08933718, 5.2074928 ])

# %%
train_mse = mean_squared_error(Y_train, Y_train_pred)
test_mse = mean_squared_error(Y_test, Y_test_pred)

# %%
print("Training MSE:", train_mse)
print("Testing MSE:", test_mse)
# Out:
# Training MSE: 6.6709894332372714
# Testing MSE: 21.11345082178243

# %%
plt.figure()
plt.scatter(X,Y)
plt.plot(X, model.predict(X))
plt.xlabel("Study Hours")
plt.ylabel("Marks")
plt.title("Linear Regression Model")
plt.show()

# %%
residuals = Y_test - Y_test_pred
residuals
# Out:
# 16    5.910663
# 2     3.383285
# 4     4.146974
# 13   -1.734870
# 18    6.674352
# 8     5.674352
# 6     4.910663
# 7    -1.207493
# Name: Marks, dtype: float64

# %%
plt.figure()
plt.scatter(X_test,residuals)
plt.axhline(0)
plt.xlabel("Study Hours (Test)")
plt.ylabel("Residuals")
plt.title("Residuals Plot (Test Data)")
plt.show()
