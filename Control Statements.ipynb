# %%
n=input(input("enter a number:"))
print("n")
# Out:
# enter a number: 3
# 3 5
# n

# %%
n=input(input("enter a number:"))
print("n")
# Out:
# enter a number: 5
# 5 7
# n

# %%
n=int(input("enter a number:"))#if statement
if n>0:
    print("given number is positive")
# Out:
# enter a number: 24
# given number is positive

# %%
n=int(input("enter a number:"))#if else condition
if n>0:
    print("given number is positive")
else:
    print("given number is negative")
# Out:
# enter a number: -4
# given number is negative

# %%
n=int(input("enter a number:"))#if el ifelse condition
if n>0:
    print("given number is positive")
elif n<0:
    print("given number is negative")
else:
    print("given number is zero")
# Out:
# enter a number: 0
# given number is zero

# %%
for i in range (0,5,1):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
n=int(input("enter a number:"))
for i in range(0,(n+1)):
    print(i)
# Out:
# enter a number: 5
# 0
# 1
# 2
# 3
# 4
# 5

# %%
n=int(input("enter a number:"))# while comdition
i=0
while(i<=n):
    print(i)
    i+=1
# Out:
# enter a number: 4
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(5):#pass
    if i==3:
        pass
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(5):#continue
    if i==3:
        continue
    print(i)
# Out:
# 0
# 1
# 2
# 4

# %%
for i in range(5):#break
    if i==3:
        break
    print(i)
# Out:
# 0
# 1
# 2

# %%
l=[]
print(l)
# Out:
# []

# %%
l=[1,2,3,5,4]
print(l)
# Out:
# [1, 2, 3, 5, 4]

# %%
l.append(6)
print(l)
# Out:
# [1, 2, 3, 5, 4, 6]

# %%
l.pop()
print(l)
# Out:
# [1, 2, 3, 5, 4]

# %%
l.sort()
print(l)
# Out:
# [1, 2, 3, 4, 5]

# %%
print(l)
# Out:
# [1, 2, 3, 4, 5]

# %%
l.count(5)
# Out:
# 1
