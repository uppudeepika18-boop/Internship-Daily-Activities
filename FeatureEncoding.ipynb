# %% [markdown]
# # Feature Encoding

# %%
import pandas as pd

# %%
df = pd.DataFrame({

"Color": ["Red", "Green", "Blue", "Green", "Red"], "Size": ["Small", "Medium", "Large", "Medium", "Small"], "City": ["Hyderabad", "Delhi", "Mumbai", "Delhi", "Chennai"], "Target": [10, 20, 15, 25, 12]

})

df
# Out:
#    Color    Size       City  Target
# 0    Red   Small  Hyderabad      10
# 1  Green  Medium      Delhi      20
# 2   Blue   Large     Mumbai      15
# 3  Green  Medium      Delhi      25
# 4    Red   Small    Chennai      12

# %% [markdown]
# # Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df["Color_Label"] = LabelEncoder().fit_transform(df["Color"])
df[["Color","Color_Label"]]
# Out:
#    Color  Color_Label
# 0    Red            2
# 1  Green            1
# 2   Blue            0
# 3  Green            1
# 4    Red            2

# %% [markdown]
# # One Hot Encoding

# %%
one_hot = pd.get_dummies(df["Color"], prefix="Color") 
one_hot
# Out:
#    Color_Blue  Color_Green  Color_Red
# 0       False        False       True
# 1       False         True      False
# 2        True        False      False
# 3       False         True      False
# 4       False        False       True

# %%
one_hot = pd.get_dummies(df, columns=["Color"]) 
one_hot
# Out:
#      Size       City  Target  Color_Label  Color_Blue  Color_Green  Color_Red
# 0   Small  Hyderabad      10            2       False        False       True
# 1  Medium      Delhi      20            1       False         True      False
# 2   Large     Mumbai      15            0        True        False      False
# 3  Medium      Delhi      25            1       False         True      False
# 4   Small    Chennai      12            2       False        False       True

# %%
from sklearn.preprocessing import OrdinalEncoder

# %% [markdown]
# # Ordinal Encoding

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
order = [["Small","Medium","Large"]]
df["Size_Ordinal"] = OrdinalEncoder(categories=order).fit_transform(df[["Size"]])
df[["Size","Size_Ordinal"]]
# Out:
#      Size  Size_Ordinal
# 0   Small           0.0
# 1  Medium           1.0
# 2   Large           2.0
# 3  Medium           1.0
# 4   Small           0.0

# %% [markdown]
# # Target Encoding

# %%
import pandas as pd
te = df.groupby("City")["Target"].mean()

df["city_Target_Enc"] = df["City"].map(te)
df[["City","city_Target_Enc"]]
# Out:
#         City  city_Target_Enc
# 0  Hyderabad             10.0
# 1      Delhi             22.5
# 2     Mumbai             15.0
# 3      Delhi             22.5
# 4    Chennai             12.0

# %% [markdown]
# # Frequency Encoding

# %%
freq = df["City"].value_counts()

df["City_Freq_Enc"] = df["City"].map(freq)
df[["City","City_Freq_Enc"]]
# Out:
#         City  City_Freq_Enc
# 0  Hyderabad              1
# 1      Delhi              2
# 2     Mumbai              1
# 3      Delhi              2
# 4    Chennai              1

# %%
f=df["City"].value_counts()
f
# Out:
# City
# Delhi        2
# Hyderabad    1
# Mumbai       1
# Chennai      1
# Name: count, dtype: int64

# %%
fe=df.groupby("City")["Target"].count()
fe
# Out:
# City
# Chennai      1
# Delhi        2
# Hyderabad    1
# Mumbai       1
# Name: Target, dtype: int64

# %% [markdown]
# # Binary Encoding

# %%
import category_encoders as ce

# %%
d_b =ce.BinaryEncoder(cols=["City"]).fit_transform(df["City"])
d_b
# Out:
#    City_0  City_1  City_2
# 0       0       0       1
# 1       0       1       0
# 2       0       1       1
# 3       0       1       0
# 4       1       0       0
