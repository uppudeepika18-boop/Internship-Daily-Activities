# %% [markdown]
# # Pandas Basic Notebook

# %% [markdown]
# # import pandas

# %%
import pandas as pd
import numpy as np
pd.__version__
# Out:
# '2.2.2'

# %% [markdown]
# # Pandas Data Structure

# %%
s = pd.Series([10,20,30])
s
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
df = pd.DataFrame({
    "name": ["Siri","Deepu"],
    "age": [19,20]
})
df
# Out:
#     name  age
# 0   Siri   19
# 1  Deepu   20

# %% [markdown]
# # Reading Data (CSV)

# %%
df = pd.read_csv('data.csv')
df
# Out:
#    city  temp  humidity condition
# 0   hyd    23        45     rainy
# 1   hyd    24        46     rainy
# 2   hyd    25        47     rainy
# 3   hyd    26        48     sunny
# 4  bang    27        49     sunny
# 5  bang    28        50     sunny
# 6  bang    29        51    cloudy
# 7  bang    30        52    cloudy

# %% [markdown]
# # writing the data into files

# %%
df.to_csv('data.csv',index=False)

# %% [markdown]
# # Exploring Data

# %%
df.head()
# Out:
#    city  temp  humidity condition
# 0   hyd    23        45     rainy
# 1   hyd    24        46     rainy
# 2   hyd    25        47     rainy
# 3   hyd    26        48     sunny
# 4  bang    27        49     sunny

# %%
df.tail(3)
# Out:
#    city  temp  humidity condition
# 5  bang    28        50     sunny
# 6  bang    29        51    cloudy
# 7  bang    30        52    cloudy

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   city       8 non-null      object
#  1   temp       8 non-null      int64
#  2   humidity   8 non-null      int64
#  3   condition  8 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 388.0+ bytes

# %%
df.shape
# Out:
# (8, 4)

# %%
df['city'][df['condition'] == 'rainy']
# Out:
# 0    hyd
# 1    hyd
# 2    hyd
# Name: city, dtype: object

# %%
df[2:5]
# Out:
#    city  temp  humidity condition
# 2   hyd    25        47     rainy
# 3   hyd    26        48     sunny
# 4  bang    27        49     sunny

# %%
df.columns
# Out:
# Index(['city', 'temp', 'humidity', 'condition'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8, step=1)

# %%
df.dtypes
# Out:
# city         object
# temp          int64
# humidity      int64
# condition    object
# dtype: object

# %%
df.city
# Out:
# 0     hyd
# 1     hyd
# 2     hyd
# 3     hyd
# 4    bang
# 5    bang
# 6    bang
# 7    bang
# Name: city, dtype: object

# %%
df[['city','condition']]
# Out:
#    city condition
# 0   hyd     rainy
# 1   hyd     rainy
# 2   hyd     rainy
# 3   hyd     sunny
# 4  bang     sunny
# 5  bang     sunny
# 6  bang    cloudy
# 7  bang    cloudy

# %%
df.temp
# Out:
# 0    23
# 1    24
# 2    25
# 3    26
# 4    27
# 5    28
# 6    29
# 7    30
# Name: temp, dtype: int64

# %% [markdown]
# # Missing Value

# %%
df.isnull()
# Out:
#     city   temp  humidity  condition
# 0  False  False     False      False
# 1  False  False     False      False
# 2  False  False     False      False
# 3  False  False     False      False
# 4  False  False     False      False
# 5  False  False     False      False
# 6  False  False     False      False
# 7  False  False     False      False

# %%
df = pd.DataFrame({
    "name" : ["siri","deepu","mouni"],
    "age" : [25,23,None]
})
df
# Out:
#     name   age
# 0   siri  25.0
# 1  deepu  23.0
# 2  mouni   NaN

# %%
df.isnull()
# Out:
#     name    age
# 0  False  False
# 1  False  False
# 2  False   True

# %%
df.isnull().sum() #total missing numbers
# Out:
# name    0
# age     1
# dtype: int64

# %%
df[df.isnull().any(axis=1)] #Show rows with missng
# Out:
#     name  age
# 2  mouni  NaN

# %%
df['age'] = df['age'].fillna(df['age'].mean())

# %%
df
# Out:
#     name   age
# 0   siri  25.0
# 1  deepu  23.0
# 2  mouni  24.0

# %%
df_clean = df.dropna()
df_clean
# Out:
#     name   age
# 0   siri  25.0
# 1  deepu  23.0

# %% [markdown]
# # Duplicates

# %%
df = pd.DataFrame({
    "name" : ["siri","deepu","siri"],
    "age" : [25,23,25]
})
df
# Out:
#     name  age
# 0   siri   25
# 1  deepu   23
# 2   siri   25

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2     True
# dtype: bool

# %%
df[df.duplicated()]
# Out:
#    name  age
# 2  siri   25

# %%
df = df.drop_duplicates()
df
# Out:
#     name  age
# 0   siri   25
# 1  deepu   23
